# %%
import pandas as pd
import matplotlib.pyplot as plt
dict={'date':['30-1-20','5-8-12','12-4-12','12-5-20'],
'price':[1000,20,52,8000],
'product_id':[101,102,103,104],
'quantity_purchased':[20,10,1,3],
'serial_no':[1,8,6,9],
'usr_id':[11,22,33,44],
'usr_type':['a','b','c','d'],
'usr_class':['upr','mid','low','mid'],
'pur_week':['mon','wed','tue','fri']}
df=pd.DataFrame(dict)
df.to_csv("df.csv")
df.head()
print(df)
stats=df.describe(include='all')
print(stats)
df.plot(x='usr_id',y='price',kind='line')
plt.show()
df[['quantity_purchased','pur_week']].plot.box()
plt.title('quantity and week value distribution')
plt.show()
# Out:
#       date  price  product_id  quantity_purchased  serial_no  usr_id usr_type  \
# 0  30-1-20   1000         101                  20          1      11        a
# 1   5-8-12     20         102                  10          8      22        b
# 2  12-4-12     52         103                   1          6      33        c
# 3  12-5-20   8000         104                   3          9      44        d
#
#   usr_class pur_week
# 0       upr      mon
# 1       mid      wed
# 2       low      tue
# 3       mid      fri
#            date        price  product_id  quantity_purchased  serial_no  \
# count         4     4.000000    4.000000            4.000000   4.000000
# unique        4          NaN         NaN                 NaN        NaN
# top     30-1-20          NaN         NaN                 NaN        NaN
# freq          1          NaN         NaN                 NaN        NaN
# mean        NaN  2268.000000  102.500000            8.500000   6.000000
# std         NaN  3848.281348    1.290994            8.582929   3.559026
# min         NaN    20.000000  101.000000            1.000000   1.000000
# 25%         NaN    44.000000  101.750000            2.500000   4.750000
# 50%         NaN   526.000000  102.500000            6.500000   7.000000
# 75%         NaN  2750.000000  103.250000           12.500000   8.250000
# max         NaN  8000.000000  104.000000           20.000000   9.000000
#
#            usr_id usr_type usr_class pur_week
# count    4.000000        4         4        4
# unique        NaN        4         3        4
# top           NaN        a       mid      mon
# freq          NaN        1         2        1
# mean    27.500000      NaN       NaN      NaN
# std     14.200939      NaN       NaN      NaN
# min     11.000000      NaN       NaN      NaN
# 25%     19.250000      NaN       NaN      NaN
# 50%     27.500000      NaN       NaN      NaN
# 75%     35.750000      NaN       NaN      NaN
# max     44.000000      NaN       NaN      NaN
